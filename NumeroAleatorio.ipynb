# %%
x0=3708
xi=0
a=0
for i in range(100):
    xi= x0*x0
    print xi
    if (len((str (xi))) <8):
        x1="0"+str(xi)
        print ("...")
    else:
        x1=""+str(xi)
    a=a+1
    b= str(a)
    print("iteracion"+b)
    un= x1[2:6]
    u1= "0."+un
    print (u1)
    x0=int (str (un))
# Out:
# 13749264
# iteracion1
# 0.7492
# 56130064
# iteracion2
# 0.1300
# 1690000
# ...
# iteracion3
# 0.6900
# 47610000
# iteracion4
# 0.6100
# 37210000
# iteracion5
# 0.2100
# 4410000
# ...
# iteracion6
# 0.4100
# 16810000
# iteracion7
# 0.8100
# 65610000
# iteracion8
# 0.6100
# 37210000
# iteracion9
# 0.2100
# 4410000
# ...
# iteracion10
# 0.4100
# 16810000
# iteracion11
# 0.8100
# 65610000
# iteracion12
# 0.6100
# 37210000
# iteracion13
# 0.2100
# 4410000
# ...
# iteracion14
# 0.4100
# 16810000
# iteracion15
# 0.8100
# 65610000
# iteracion16
# 0.6100
# 37210000
# iteracion17
# 0.2100
# 4410000
# ...
# iteracion18
# 0.4100
# 16810000
# iteracion19
# 0.8100
# 65610000
# iteracion20
# 0.6100
# 37210000
# iteracion21
# 0.2100
# 4410000
# ...
# iteracion22
# 0.4100
# 16810000
# iteracion23
# 0.8100
# 65610000
# iteracion24
# 0.6100
# 37210000
# iteracion25
# 0.2100
# 4410000
# ...
# iteracion26
# 0.4100
# 16810000
# iteracion27
# 0.8100
# 65610000
# iteracion28
# 0.6100
# 37210000
# ...
